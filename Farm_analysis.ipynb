# %% [markdown]
# В данном мини-проекте проведем ABC-анализ, XYZ-анализ и анализ динамики продаж товаров аптечной сети.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# Настроим максимальное значение отображаемых колонок, а также формат значений с плавающей точкой. Загрузим датафрейм.

# %%
pd.set_option('display.max_columns', 40)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df = pd.read_csv(r'C:\Users\yarus\Downloads\Проект\Проект\data\data.csv', encoding='1251')

# %%
df.head()
# Out:
#        DR_Dat    DR_Tim  DR_NChk  DR_NDoc  DR_Apt  DR_Kkm  \
# 0  2022-08-11  10:15:35     2173  2004598       2   22577
# 1  2022-08-11  10:27:46     2174  2004598       2   22577
# 2  2022-08-11  10:27:46     2174  2004598       2   22577
# 3  2022-08-11  10:27:46     2174  2004598       2   22577
# 4  2022-08-11  10:33:56     2175  2004598       2   22577
#
#                 DR_TDoc  DR_TPay  DR_CDrugs  \
# 0  Розничная реализация       18      45399
# 1  Розничная реализация       15     261519
# 2  Розничная реализация       15     460864
# 3  Розничная реализация       15     172823
# 4  Розничная реализация       18      79056
#
#                                            DR_NDrugs        DR_Suppl  \
# 0  ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-...  Катрен г.Химки
# 1            ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ.  Катрен г.Химки
# 2  СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ...  Катрен г.Химки
# 3  СОФЬЯ ГХК КРЕМ Д/ТЕЛА ХОНДРОИТИН+ГЛЮКОЗАМИН 12...  Катрен г.Химки
# 4                   ГАЛВУС 50МГ. №28 ТАБ. /НОВАРТИС/  Катрен г.Химки
#
#                                     DR_Prod  DR_Kol  DR_CZak  DR_CRoz  \
# 0  Д-р Редди с Лабораторис Лтд / Dr.REDDY's    1.00    41.08    51.00
# 1                         ФЛОРА КАВКАЗА ОАО    1.00    18.61    31.00
# 2                           КОРОЛЕВФАРМ ООО    1.00   132.69   209.00
# 3                           КОРОЛЕВФАРМ ООО    1.00   133.65   210.00
# 4                         Новартис Фарма АГ    1.00   709.95   787.00
#
#    DR_SDisc  DR_CDisc       DR_BCDisc  DR_TabEmpl  DR_VZak  DR_Pos
# 0     12.00    925.00 200000000492.00         205        1    1.00
# 1      3.00      9.00 200010010204.00         205        1    1.00
# 2     20.00      9.00 200010010204.00         205        1    2.00
# 3     21.00      9.00 200010010204.00         205        1    3.00
# 4     49.00    925.00 200000000492.00         205        1    1.00

# %% [markdown]
# ## ABC-анализ

# %% [markdown]
# Сгруппируем по наименованию товара, и посчитаем его суммарное количество продаж.

# %%
groupped_df = df.groupby('DR_NDrugs', as_index=False).agg({'DR_Kol': sum})

# %%
groupped_df.head()
# Out:
#                                            DR_NDrugs  DR_Kol
# 0  7 СЕМЬ ДНЕЙ МАСКА Д/ЛИЦА СУББОТА РОМАНТ. ПЕРЕД...    1.00
# 1  9 МЕСЯЦЕВ ФОЛИЕВАЯ К-ТА 0,4МГ. №30 ТАБ. П/П/О ...    1.00
# 2    911-ГЕЛЬ-БАЛЬЗАМ Д/СУСТАВОВ ОКОПНИК 100МЛ. ТУБА    2.00
# 3       911-ГЕЛЬ-БАЛЬЗАМ Д/СУСТАВОВ САБЕЛЬНИК 100МЛ.    2.00
# 4  911-ГЕЛЬ-БАЛЬЗАМ Д/ТЕЛА БИШОФИТ П/БОЛИ В СУСТА...    1.00

# %%
groupped_df['DR_Kol'].max()
# Out:
# 126.0

# %% [markdown]
# Посмотрим на доли в общем объеме проданного товара.

# %%
groupped_df = (groupped_df['DR_Kol'] / sum(groupped_df['DR_Kol'])).sort_values(ascending=False)

# %%
groupped_df.head()
# Out:
# 1191   0.03
# 1769   0.01
# 1077   0.01
# 842    0.01
# 1426   0.01
# Name: DR_Kol, dtype: float64

# %% [markdown]
# Посчитаем доли накопительно, чтобы выделить 80 % и 95 % срезы по объему проданных товаров.

# %%
groupped_df = groupped_df.cumsum().reset_index()

# %%
groupped_df.head()
# Out:
#    index  DR_Kol
# 0   1191    0.03
# 1   1769    0.04
# 2   1077    0.05
# 3    842    0.06
# 4   1426    0.07

# %% [markdown]
# Разделим товары на три группы по объему продаж.

# %%
groupped_df['abc'] = np.where(groupped_df['DR_Kol'] < 0.8, 'A', np.where(groupped_df['DR_Kol'] < 0.95, 'B', 'C'))

# %%
groupped_df[groupped_df['abc'] == 'B'].head()
# Out:
#      index  DR_Kol abc
# 938   1817    0.80   B
# 939   1814    0.80   B
# 940   1812    0.80   B
# 941   1811    0.80   B
# 942   1809    0.80   B

# %% [markdown]
# Сгруппируем по наименованию товара, и посчитаем его суммарное количество продаж и суммарную стоимость продаж.

# %%
groupped_df = df.groupby('DR_NDrugs', as_index=False).agg({'DR_Kol': sum, 'DR_CRoz': sum})

# %%
groupped_df.head()
# Out:
#                                            DR_NDrugs  DR_Kol  DR_CRoz
# 0  7 СЕМЬ ДНЕЙ МАСКА Д/ЛИЦА СУББОТА РОМАНТ. ПЕРЕД...    1.00    93.00
# 1  9 МЕСЯЦЕВ ФОЛИЕВАЯ К-ТА 0,4МГ. №30 ТАБ. П/П/О ...    1.00   144.00
# 2    911-ГЕЛЬ-БАЛЬЗАМ Д/СУСТАВОВ ОКОПНИК 100МЛ. ТУБА    2.00   216.00
# 3       911-ГЕЛЬ-БАЛЬЗАМ Д/СУСТАВОВ САБЕЛЬНИК 100МЛ.    2.00   208.00
# 4  911-ГЕЛЬ-БАЛЬЗАМ Д/ТЕЛА БИШОФИТ П/БОЛИ В СУСТА...    1.00   100.00

# %% [markdown]
# Посмотрим на доли в общем количестве товаров.

# %%
groupped_df['rel_kol'] = groupped_df['DR_Kol'] / sum(groupped_df['DR_Kol'])

# %%
groupped_df.head()
# Out:
#                                            DR_NDrugs  DR_Kol  DR_CRoz  rel_kol
# 0  7 СЕМЬ ДНЕЙ МАСКА Д/ЛИЦА СУББОТА РОМАНТ. ПЕРЕД...    1.00    93.00     0.00
# 1  9 МЕСЯЦЕВ ФОЛИЕВАЯ К-ТА 0,4МГ. №30 ТАБ. П/П/О ...    1.00   144.00     0.00
# 2    911-ГЕЛЬ-БАЛЬЗАМ Д/СУСТАВОВ ОКОПНИК 100МЛ. ТУБА    2.00   216.00     0.00
# 3       911-ГЕЛЬ-БАЛЬЗАМ Д/СУСТАВОВ САБЕЛЬНИК 100МЛ.    2.00   208.00     0.00
# 4  911-ГЕЛЬ-БАЛЬЗАМ Д/ТЕЛА БИШОФИТ П/БОЛИ В СУСТА...    1.00   100.00     0.00

# %%
groupped_df = groupped_df.sort_values('rel_kol', ascending=False)

# %%
groupped_df.head()
# Out:
#                                               DR_NDrugs  DR_Kol  DR_CRoz  \
# 1191                                              ПАКЕТ  126.00   248.00
# 1769  ЦЕФТРИАКСОН 1Г. №1 ПОР. Д/Р-РА Д/В/В,В/М ФЛ. /...   60.00  2280.00
# 1077   НАФТИЗИН 0,1% 15МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. /ЛЕККО/   48.00   552.00
# 842         ЛЕЙКОПЛАСТЫРЬ БАКТЕР. 2,5Х7,2 №1 /ВЕРОФАРМ/   40.00    28.00
# 1426  СНУП 0,1% 90МКГ/ДОЗА 15МЛ. НАЗАЛ.СПРЕЙ ФЛ. /ШТ...   35.00  4215.00
#
#       rel_kol
# 1191     0.03
# 1769     0.01
# 1077     0.01
# 842      0.01
# 1426     0.01

# %% [markdown]
# Посчитаем доли накопительно.

# %%
groupped_df['cumsum_kol'] = groupped_df['rel_kol'].cumsum()

# %%
groupped_df.head()
# Out:
#                                               DR_NDrugs  DR_Kol  DR_CRoz  \
# 1191                                              ПАКЕТ  126.00   248.00
# 1769  ЦЕФТРИАКСОН 1Г. №1 ПОР. Д/Р-РА Д/В/В,В/М ФЛ. /...   60.00  2280.00
# 1077   НАФТИЗИН 0,1% 15МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. /ЛЕККО/   48.00   552.00
# 842         ЛЕЙКОПЛАСТЫРЬ БАКТЕР. 2,5Х7,2 №1 /ВЕРОФАРМ/   40.00    28.00
# 1426  СНУП 0,1% 90МКГ/ДОЗА 15МЛ. НАЗАЛ.СПРЕЙ ФЛ. /ШТ...   35.00  4215.00
#
#       rel_kol  cumsum_kol
# 1191     0.03        0.03
# 1769     0.01        0.04
# 1077     0.01        0.05
# 842      0.01        0.06
# 1426     0.01        0.07

# %% [markdown]
# Разделим товары на три группы по объему продаж, используя библиотеку numpy.

# %%
groupped_df['abc_kol'] = np.where(groupped_df['cumsum_kol'] < 0.8, 'A', np.where(groupped_df['cumsum_kol'] < 0.95, 'B', 'C'))

# %%
groupped_df
# Out:
#                                               DR_NDrugs  DR_Kol  DR_CRoz  \
# 1191                                              ПАКЕТ  126.00   248.00
# 1769  ЦЕФТРИАКСОН 1Г. №1 ПОР. Д/Р-РА Д/В/В,В/М ФЛ. /...   60.00  2280.00
# 1077   НАФТИЗИН 0,1% 15МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. /ЛЕККО/   48.00   552.00
# 842         ЛЕЙКОПЛАСТЫРЬ БАКТЕР. 2,5Х7,2 №1 /ВЕРОФАРМ/   40.00    28.00
# 1426  СНУП 0,1% 90МКГ/ДОЗА 15МЛ. НАЗАЛ.СПРЕЙ ФЛ. /ШТ...   35.00  4215.00
# ...                                                 ...     ...      ...
# 1067  НАТРИЯ ХЛОРИД 0,9% 400МЛ. №16 Р-Р Д/ИНФ. КОНТ....    0.06   669.00
# 1513  СФМ ШПРИЦ 2МЛ. 3-Х КОМП. 0,63Х32ММ 23G №100 [SFM]    0.05   918.00
# 490   ДЕРМАГРИП ХАЙ РИСК ПЕРЧАТКИ ЛАТ. СМОТР. Н/СТЕР...    0.04  2000.00
# 1516   СФМ ШПРИЦ 50МЛ. 3-Х КОМП. 1,2X40ММ 18G №25 [SFM]    0.04  1324.00
# 1503  СФМ ПЕРЧАТКИ СМОТР. Н/СТЕР. ЛАТ. ТЕКСТУРИР. Н/...    0.02   988.00
#
#       rel_kol  cumsum_kol abc_kol
# 1191     0.03        0.03       A
# 1769     0.01        0.04       A
# 1077     0.01        0.05       A
# 842      0.01        0.06       A
# 1426     0.01        0.07       A
# ...       ...         ...     ...
# 1067     0.00        1.00       C
# 1513     0.00        1.00       C
# 490      0.00        1.00       C
# 1516     0.00        1.00       C
# 1503     0.00        1.00       C
#
# [1876 rows x 6 columns]

# %% [markdown]
# Промаркеруем товары также на три группы, но уже по выручке от товара.

# %%
groupped_df['rel_roz'] = groupped_df['DR_CRoz'] / sum(groupped_df['DR_CRoz'])
groupped_df = groupped_df.sort_values('rel_roz', ascending=False)
groupped_df['cumsum_roz'] = groupped_df['rel_roz'].cumsum()
groupped_df['abc_roz'] = np.where(groupped_df['cumsum_roz'] < 0.8, 'A', np.where(groupped_df['cumsum_roz'] < 0.95, 'B', 'C'))

# %%
groupped_df
# Out:
#                                               DR_NDrugs  DR_Kol  DR_CRoz  \
# 1553  ТЕРАФЛЮ ЛИМОН ОТ ГРИППА И ПРОСТУДЫ 22,1Г. №14 ...    7.00 15638.00
# 1097  НИМЕСИЛ 100МГ. 2Г. №30 ГРАН. Д/СУСП. Д/ПРИЕМА ...    2.80 14445.00
# 619                 ИНГАВИРИН 90МГ. №10 КАПС. /ВАЛЕНТА/   18.00 13750.00
# 1724  ХАРТМАНН БРАНОЛИНД H ПОВЯЗКА СТЕР. 10Х20СМ. №3...    0.17 12908.00
# 1825  ЭЛИКВИС 2,5МГ. №60 ТАБ. П/П/О /ПФАЙЗЕР/БРИСТОЛ...    5.00 12731.00
# ...                                                 ...     ...      ...
# 768   КОНТЕЙНЕР Д/СБОРА БИОМАТЕРИАЛА 60МЛ. +ШПАТЕЛЬ ...    1.00    10.00
# 165   АСКОРБИНОВАЯ К-ТА 25МГ. АПЕЛЬСИН №10 ТАБ. КРУТ...    1.00    10.00
# 169   АСКОРБИНОВАЯ К-ТА 25МГ. №10 ТАБ. КРУТКА САХ. /...    7.00     9.00
# 710                   КЛИНСА БАХИЛЫ СТАНДАРТ №2 (1ПАРА)    2.00     7.00
# 812                                Карта LOYALITY 0,01Р   34.00     0.34
#
#       rel_kol  cumsum_kol abc_kol  rel_roz  cumsum_roz abc_roz
# 1553     0.00        0.36       A     0.01        0.01       A
# 1097     0.00        0.61       A     0.01        0.02       A
# 619      0.00        0.19       A     0.01        0.03       A
# 1724     0.00        1.00       C     0.01        0.04       A
# 1825     0.00        0.43       A     0.01        0.05       A
# ...       ...         ...     ...      ...         ...     ...
# 768      0.00        1.00       C     0.00        1.00       C
# 165      0.00        0.92       B     0.00        1.00       C
# 169      0.00        0.34       A     0.00        1.00       C
# 710      0.00        0.67       A     0.00        1.00       C
# 812      0.01        0.08       A     0.00        1.00       C
#
# [1876 rows x 9 columns]

# %%
groupped_df[['DR_CRoz', 'DR_Kol', 'abc_kol', 'abc_roz']].reset_index().sort_values('DR_CRoz', ascending=False)
# Out:
#       index  DR_CRoz  DR_Kol abc_kol abc_roz
# 0      1553 15638.00    7.00       A       A
# 1      1097 14445.00    2.80       A       A
# 2       619 13750.00   18.00       A       A
# 3      1724 12908.00    0.17       C       A
# 4      1825 12731.00    5.00       A       A
# ...     ...      ...     ...     ...     ...
# 1871    768    10.00    1.00       C       C
# 1872    165    10.00    1.00       B       C
# 1873    169     9.00    7.00       A       C
# 1874    710     7.00    2.00       A       C
# 1875    812     0.34   34.00       A       C
#
# [1876 rows x 5 columns]

# %% [markdown]
# Оставим только интересующие нас поля.

# %%
df1 = df[['DR_NDrugs', 'DR_Kol', 'DR_CRoz']]
df1.columns
# Out:
# Index(['DR_NDrugs', 'DR_Kol', 'DR_CRoz'], dtype='object')

# %%
df1.head()
# Out:
#                                            DR_NDrugs  DR_Kol  DR_CRoz
# 0  ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-...    1.00    51.00
# 1            ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ.    1.00    31.00
# 2  СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ...    1.00   209.00
# 3  СОФЬЯ ГХК КРЕМ Д/ТЕЛА ХОНДРОИТИН+ГЛЮКОЗАМИН 12...    1.00   210.00
# 4                   ГАЛВУС 50МГ. №28 ТАБ. /НОВАРТИС/    1.00   787.00

# %% [markdown]
# Напишем функцию для маркировки на АВС-группы по переданным полям.

# %%
def perform_abc(df, index):
    """
    На вход подается датафрейм пандас...
    """
    cols = list(df.columns)
    cols.remove(index)
    groupped_df = df.groupby(index).agg({col: sum for col in cols})
    for col in cols:
        groupped_df[f'rel_{col}'] = groupped_df[col] / sum(groupped_df[col])
        groupped_df = groupped_df.sort_values(f'rel_{col}', ascending=False)
        groupped_df[f'cumsum_{col}'] = groupped_df[f'rel_{col}'].cumsum()
        groupped_df[f'abc_{col}'] = np.where(groupped_df[f'cumsum_{col}'] < 0.8, 'A', np.where(groupped_df[f'cumsum_{col}'] < 0.95, 'B', 'C'))
    return groupped_df[cols + [f'abc_{col}' for col in cols]]

# %% [markdown]
# Проведем АВС-анализ по количесству продаж и выручке, использовав уже написанную функцию.

# %%
perform_abc(df1, index='DR_NDrugs')
# Out:
#                                                     DR_Kol  DR_CRoz  \
# DR_NDrugs
# ТЕРАФЛЮ ЛИМОН ОТ ГРИППА И ПРОСТУДЫ 22,1Г. №14 П...    7.00 15638.00
# НИМЕСИЛ 100МГ. 2Г. №30 ГРАН. Д/СУСП. Д/ПРИЕМА В...    2.80 14445.00
# ИНГАВИРИН 90МГ. №10 КАПС. /ВАЛЕНТА/                  18.00 13750.00
# ХАРТМАНН БРАНОЛИНД H ПОВЯЗКА СТЕР. 10Х20СМ. №30...    0.17 12908.00
# ЭЛИКВИС 2,5МГ. №60 ТАБ. П/П/О /ПФАЙЗЕР/БРИСТОЛ-...    5.00 12731.00
# ...                                                    ...      ...
# КОНТЕЙНЕР Д/СБОРА БИОМАТЕРИАЛА 60МЛ. +ШПАТЕЛЬ С...    1.00    10.00
# АСКОРБИНОВАЯ К-ТА 25МГ. АПЕЛЬСИН №10 ТАБ. КРУТК...    1.00    10.00
# АСКОРБИНОВАЯ К-ТА 25МГ. №10 ТАБ. КРУТКА САХ. /А...    7.00     9.00
# КЛИНСА БАХИЛЫ СТАНДАРТ №2 (1ПАРА)                     2.00     7.00
# Карта LOYALITY 0,01Р                                 34.00     0.34
#
#                                                    abc_DR_Kol abc_DR_CRoz
# DR_NDrugs
# ТЕРАФЛЮ ЛИМОН ОТ ГРИППА И ПРОСТУДЫ 22,1Г. №14 П...          A           A
# НИМЕСИЛ 100МГ. 2Г. №30 ГРАН. Д/СУСП. Д/ПРИЕМА В...          A           A
# ИНГАВИРИН 90МГ. №10 КАПС. /ВАЛЕНТА/                         A           A
# ХАРТМАНН БРАНОЛИНД H ПОВЯЗКА СТЕР. 10Х20СМ. №30...          C           A
# ЭЛИКВИС 2,5МГ. №60 ТАБ. П/П/О /ПФАЙЗЕР/БРИСТОЛ-...          A           A
# ...                                                       ...         ...
# КОНТЕЙНЕР Д/СБОРА БИОМАТЕРИАЛА 60МЛ. +ШПАТЕЛЬ С...          C           C
# АСКОРБИНОВАЯ К-ТА 25МГ. АПЕЛЬСИН №10 ТАБ. КРУТК...          B           C
# АСКОРБИНОВАЯ К-ТА 25МГ. №10 ТАБ. КРУТКА САХ. /А...          A           C
# КЛИНСА БАХИЛЫ СТАНДАРТ №2 (1ПАРА)                           A           C
# Карта LOYALITY 0,01Р                                        A           C
#
# [1876 rows x 4 columns]

# %% [markdown]
# ## Динамика продаж
# Считаем таблицу с большим количеством данных (за 5 дней).

# %%
df = pd.read_csv(r"C:\Users\yarus\Downloads\Проект\Проект\data\data1.csv", encoding='1251')

# %%
df.head()
# Out:
#        DR_Dat    DR_Tim  DR_NChk   DR_NDoc  DR_Apt  DR_Kkm  \
# 0  2022-08-01  08:06:18     1272  13002561      13   22589
# 1  2022-08-01  08:38:53     1273  13002561      13   22589
# 2  2022-08-01  08:55:38     1274  13002561      13   22589
# 3  2022-08-01  09:00:40     1275  13002561      13   22589
# 4  2022-08-01  09:04:05     1276  13002561      13   22589
#
#                 DR_TDoc  DR_TPay  DR_CDrugs  \
# 0  Розничная реализация       18     144734
# 1  Розничная реализация       15      69661
# 2  Розничная реализация       18     190635
# 3  Розничная реализация       18     276370
# 4  Розничная реализация       15       2303
#
#                                            DR_NDrugs  \
# 0                            ГАСТАЛ №12 ТАБ. Д/РАСС.
# 1   ТОБРОПТ 0,3% 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /РОМФАРМ/
# 2  ЭЛИКВИС 5МГ. №60 ТАБ. П/П/О /ПФАЙЗЕР/БРИСТОЛ-М...
# 3  АРБИДОЛ МАКСИМУМ 200МГ. №10 КАПС. /ОТИСИФАРМ/Ф...
# 4                   ЭНАМ 2,5МГ. №20 ТАБ. /Д-Р РЕДДИ/
#
#                         DR_Suppl                                   DR_Prod  \
# 0                          Пульс        TEVA Pharvaceutical Industries Ltd
# 1                          Пульс              РОМФАРМ КОМПАНИ ( ROMPHARM )
# 2  ГРАНД КАПИТАЛ СМОЛЕНСК ООО ФК                                   Пфайзер
# 3                          Пульс                             ОТИСИФАРМ ПАО
# 4                         Протек  Д-р Редди с Лабораторис Лтд / Dr.REDDY's
#
#    DR_Kol  DR_CZak  DR_CRoz  DR_SDisc  DR_CDisc       DR_BCDisc  DR_TabEmpl  \
# 0    1.00   196.71   270.00      0.00       NaN             NaN          29
# 1    1.00   106.21   127.00      6.00      9.00 200010004357.00          29
# 2    1.00  2320.99  2563.00     76.00      9.00 200010018491.00          29
# 3    1.00   445.39   541.00      0.00       NaN             NaN          29
# 4    1.00    18.04    22.00      1.00      9.00 200010000734.00          29
#
#    DR_VZak  DR_Pos
# 0        1    1.00
# 1        1    1.00
# 2        1    1.00
# 3        1    1.00
# 4        1    5.00

# %%
df.DR_Dat.unique()
# Out:
# array(['2022-08-01', '2022-08-02', '2022-08-03', '2022-08-04',
#        '2022-08-05'], dtype=object)

# %%
df.DR_Apt.unique()
# Out:
# array([13], dtype=int64)

# %% [markdown]
# Произведем рассчет выручки по каждой дате.

# %%
df = pd.read_csv(r"C:\Users\yarus\Downloads\Проект\Проект\data\data1.csv", encoding='1251')
df = df.groupby('DR_Dat').apply(lambda x: sum(x['DR_Kol']*x['DR_CRoz'] - x['DR_SDisc'])).reset_index()
df
# Out:
#        DR_Dat        0
# 0  2022-08-01 84681.52
# 1  2022-08-02 71389.37
# 2  2022-08-03 78050.82
# 3  2022-08-04 59187.36
# 4  2022-08-05 56458.81

# %% [markdown]
# Используем pandas-серию для именования рассчетного столбца.

# %%
df = pd.read_csv(r"C:\Users\yarus\Downloads\Проект\Проект\data\data1.csv", encoding='1251')
df = df.groupby('DR_Dat').apply(lambda x: pd.Series({'revenue': sum(x['DR_Kol']*x['DR_CRoz'] - x['DR_SDisc'])})).reset_index()
df
# Out:
#        DR_Dat  revenue
# 0  2022-08-01 84681.52
# 1  2022-08-02 71389.37
# 2  2022-08-03 78050.82
# 3  2022-08-04 59187.36
# 4  2022-08-05 56458.81

# %% [markdown]
# Либо можно было применить поверх переименование полей в датафрейме.

# %%
df.columns = ['DR_Dat', 'revenue']

# %%
df
# Out:
#        DR_Dat  revenue
# 0  2022-08-01 84681.52
# 1  2022-08-02 71389.37
# 2  2022-08-03 78050.82
# 3  2022-08-04 59187.36
# 4  2022-08-05 56458.81

# %% [markdown]
# Рассмотрим динамику выручки по дням, а именно процент изменения относительно прошедшего дня.

# %%
df['revenue_d'] = df['revenue'].rolling(2).apply(lambda x: (x.iloc[1] - x.iloc[0])/x.iloc[0])
df
# Out:
#        DR_Dat  revenue  revenue_d
# 0  2022-08-01 84681.52        NaN
# 1  2022-08-02 71389.37      -0.16
# 2  2022-08-03 78050.82       0.09
# 3  2022-08-04 59187.36      -0.24
# 4  2022-08-05 56458.81      -0.05

# %% [markdown]
# Либо можно было применить метод shift.

# %%
df['revenue_shifted'] = df['revenue'].shift(1)
df
# Out:
#        DR_Dat  revenue  revenue_d  revenue_shifted
# 0  2022-08-01 84681.52        NaN              NaN
# 1  2022-08-02 71389.37      -0.16         84681.52
# 2  2022-08-03 78050.82       0.09         71389.37
# 3  2022-08-04 59187.36      -0.24         78050.82
# 4  2022-08-05 56458.81      -0.05         59187.36

# %%
df['revenue_d2'] = (df['revenue'] - df['revenue_shifted']) / df['revenue_shifted']
df
# Out:
#        DR_Dat  revenue  revenue_d  revenue_shifted  revenue_d2
# 0  2022-08-01 84681.52        NaN              NaN         NaN
# 1  2022-08-02 71389.37      -0.16         84681.52       -0.16
# 2  2022-08-03 78050.82       0.09         71389.37        0.09
# 3  2022-08-04 59187.36      -0.24         78050.82       -0.24
# 4  2022-08-05 56458.81      -0.05         59187.36       -0.05

# %% [markdown]
# Также есть уже встроенный метод, считающий относительное изменение на заданное количество смещения.

# %%
df['revenue_d3'] = df['revenue'].pct_change(1)
df
# Out:
#        DR_Dat  revenue  revenue_d  revenue_shifted  revenue_d2  revenue_d3
# 0  2022-08-01 84681.52        NaN              NaN         NaN         NaN
# 1  2022-08-02 71389.37      -0.16         84681.52       -0.16       -0.16
# 2  2022-08-03 78050.82       0.09         71389.37        0.09        0.09
# 3  2022-08-04 59187.36      -0.24         78050.82       -0.24       -0.24
# 4  2022-08-05 56458.81      -0.05         59187.36       -0.05       -0.05

# %% [markdown]
# ## XYZ-анализ

# %%
df = pd.read_csv(r"C:\Users\yarus\Downloads\Проект\Проект\data\data1.csv", encoding='1251')

# %%
df.head()
# Out:
#        DR_Dat    DR_Tim  DR_NChk   DR_NDoc  DR_Apt  DR_Kkm  \
# 0  2022-08-01  08:06:18     1272  13002561      13   22589
# 1  2022-08-01  08:38:53     1273  13002561      13   22589
# 2  2022-08-01  08:55:38     1274  13002561      13   22589
# 3  2022-08-01  09:00:40     1275  13002561      13   22589
# 4  2022-08-01  09:04:05     1276  13002561      13   22589
#
#                 DR_TDoc  DR_TPay  DR_CDrugs  \
# 0  Розничная реализация       18     144734
# 1  Розничная реализация       15      69661
# 2  Розничная реализация       18     190635
# 3  Розничная реализация       18     276370
# 4  Розничная реализация       15       2303
#
#                                            DR_NDrugs  \
# 0                            ГАСТАЛ №12 ТАБ. Д/РАСС.
# 1   ТОБРОПТ 0,3% 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /РОМФАРМ/
# 2  ЭЛИКВИС 5МГ. №60 ТАБ. П/П/О /ПФАЙЗЕР/БРИСТОЛ-М...
# 3  АРБИДОЛ МАКСИМУМ 200МГ. №10 КАПС. /ОТИСИФАРМ/Ф...
# 4                   ЭНАМ 2,5МГ. №20 ТАБ. /Д-Р РЕДДИ/
#
#                         DR_Suppl                                   DR_Prod  \
# 0                          Пульс        TEVA Pharvaceutical Industries Ltd
# 1                          Пульс              РОМФАРМ КОМПАНИ ( ROMPHARM )
# 2  ГРАНД КАПИТАЛ СМОЛЕНСК ООО ФК                                   Пфайзер
# 3                          Пульс                             ОТИСИФАРМ ПАО
# 4                         Протек  Д-р Редди с Лабораторис Лтд / Dr.REDDY's
#
#    DR_Kol  DR_CZak  DR_CRoz  DR_SDisc  DR_CDisc       DR_BCDisc  DR_TabEmpl  \
# 0    1.00   196.71   270.00      0.00       NaN             NaN          29
# 1    1.00   106.21   127.00      6.00      9.00 200010004357.00          29
# 2    1.00  2320.99  2563.00     76.00      9.00 200010018491.00          29
# 3    1.00   445.39   541.00      0.00       NaN             NaN          29
# 4    1.00    18.04    22.00      1.00      9.00 200010000734.00          29
#
#    DR_VZak  DR_Pos
# 0        1    1.00
# 1        1    1.00
# 2        1    1.00
# 3        1    1.00
# 4        1    5.00

# %% [markdown]
# Посмотрим на количество продаваемого товара в разрезе каждого дня.

# %%
df = df.groupby(['DR_Dat', 'DR_NDrugs'], as_index= False).agg({'DR_Kol': sum})
df
# Out:
#           DR_Dat                                          DR_NDrugs  DR_Kol
# 0     2022-08-01  911-ВЕНОЛГОН ГЕЛЬ Д/НОГ ПРИ ТЯЖЕСТИ,БОЛИ,ОТЕКА...    1.00
# 1     2022-08-01         L-ТИРОКСИН 100МКГ. №100 ТАБ. /БЕРЛИН ХЕМИ/    1.00
# 2     2022-08-01           L-ТИРОКСИН 50МКГ. №50 ТАБ. /БЕРЛИН ХЕМИ/    1.00
# 3     2022-08-01          L-ТИРОКСИН 75МКГ. №100 ТАБ. /БЕРЛИН ХЕМИ/    2.00
# 4     2022-08-01              NF ВАТА ХИРУРГ. СТЕР. 100Г. /НЬЮФАРМ/    1.00
# ...          ...                                                ...     ...
# 1084  2022-08-05   ЭВО ПАНТЕНОЛ ПОМАДА ГИГИЕН. 2,8Г. [EVO] /АВАНТА/    1.00
# 1085  2022-08-05  ЭМОКСИПИН 10МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ. КРЫШ/КАП.    2.00
# 1086  2022-08-05  ЭСВИЦИН СР-ВО П/ОБЛЫСЕНИЯ ЛОСЬОН-ТОНИК 250МЛ. ...    1.00
# 1087  2022-08-05                       ЭТОРИАКС 90МГ. №7 ТАБ. П/П/О    1.00
# 1088  2022-08-05  ЮНИДОКС СОЛЮТАБ 100МГ. №20 ТАБ.ДИСПЕРГ. /АСТЕЛ...    1.00
#
# [1089 rows x 3 columns]

# %% [markdown]
# Отберем только те позиции, которые продавались больше одного дня.

# %%
df1 = df.groupby('DR_NDrugs').agg({'DR_Dat': 'count'}).reset_index()
xyz_names = list(df1[df1['DR_Dat'] > 1]['DR_NDrugs'])
xyz_names
# Out:
# ['L-ТИРОКСИН 50МКГ. №50 ТАБ. /БЕРЛИН ХЕМИ/',
#  'L-ТИРОКСИН 75МКГ. №100 ТАБ. /БЕРЛИН ХЕМИ/',
#  'АЗАРГА 10МГ/МЛ.+5МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП.',
#  'АМОКСИЦИЛЛИН 500МГ. №16 КАПС. /ХЕМОФАРМ/',
#  'АРБИДОЛ МАКСИМУМ 200МГ. №10 КАПС. /ОТИСИФАРМ/ФАРМСТАНДАРТ/',
#  'АСЕПТИКА САЛФЕТКА СПИРТОВАЯ 60Х100 №20',
#  'АСКОРБИНКА ЛУНТИК ВИТ.С КЛУБНИКА №10 ТАБ. (30Г.) /ФАРМ-ПРО/ТИГОДА-ФАРМ/',
#  'АСКОРБИНКА ЛУНТИК ВИТ.С №10 ТАБ. (30Г.) /ФАРМ-ПРО/ТИГОДА-ФАРМ/',
#  'АСКОРБИНОВАЯ К-ТА 25МГ. ВИШНЯ №10 ТАБ. КРУТКА САХ. /АСКОПРОМ/',
#  'АСКОРБИНОВАЯ К-ТА 25МГ. ЯБЛОКО №10 ТАБ. КРУТКА САХ. /АСКОПРОМ/',
#  'АСПАРКАМ №60 ТАБ. /ФАРМАПОЛ-ВОЛГА/',
#  'АСПЕРА СУПЕРЧИСТОТЕЛ 3МЛ. ФЛ.',
#  'АТЕНОЛОЛ РЕНЕВАЛ 50МГ. №30 ТАБ. /ОБНОВЛЕНИЕ/',
#  'АТОПИК КРЕМ-СТИК УСПОКАИВАЮЩИЙ Д/ДЕТ. 0+ 4,9МЛ. ПЕНАЛ [ATOPIC]',
#  'АТОРВАСТАТИН-СЗ 20МГ. №60 ТАБ. П/П/О /СЕВЕРНАЯ ЗВЕЗДА/',
#  'АФОБАЗОЛ 10МГ. №60 ТАБ.',
#  'АЦЕТИЛСАЛИЦИЛОВАЯ К-ТА 500МГ. №20 ТАБ. /ФАРМСТАНДАРТ/',
#  'АЦИКЛОВИР-БЕЛУПО 5% 10Г. №1 КРЕМ Д/НАРУЖ.ПРИМ. ТУБА /БЕЛУПО/',
#  'БЕТАГИСТИН-СЗ 16МГ. №60 ТАБ. /СЕВЕРНАЯ ЗВЕЗДА/',
#  'БЕТАЛОК ЗОК 25МГ. №14 ТАБ.ПРОЛОНГ. П/О /АСТРА ЗЕНЕКА/',
#  'БИОВИТА ВОДА ПИТЬЕВАЯ СТРУКТУР. 0,6Л. Н/ГАЗ. [BIOVITA]',
#  'БИСОПРОЛОЛ 2,5МГ. №30 ТАБ. П/П/О /ВЕРТЕКС/',
#  'БИСОПРОЛОЛ 2,5МГ. №60 ТАБ. П/О /ВЕРТЕКС/',
#  'БИСОПРОЛОЛ 5МГ. №60 ТАБ. П/П/О /ВЕРТЕКС/',
#  'БИФИДУМБАКТЕРИН 5ДОЗ №10 ЛИОФ. Д/СУСП. Д/ПРИЕМА ВНУТРЬ И МЕСТ.ПРИМ. ФЛ. /ЭКОПОЛИС/',
#  'БРАЛ 500МГ. №20 ТАБ.',
#  'БРИЛЛИАНТОВЫЙ ЗЕЛЕН 1% 25МЛ. №1 СПИРТ. Р-Р Д/НАРУЖ.ПРИМ. ФЛ. /САМАРАМЕДПРОМ/ЖЕНЕЛ/',
#  'ВАЗЕЛИН 30Г. МАЗЬ Д/НАРУЖ.ПРИМ. ТУБА /МУРОМСКИЙ/',
#  'ВАЛЕРИАНЫ НАСТОЙКА 25МЛ. ФЛ. /ГИППОКРАТ/',
#  'ВАЛИДОЛ 60МГ. №10 ТАБ. ПОДЪЯЗЫЧ. /ФАРМСТАНДАРТ/',
#  'ВАЛОКОРДИН 20МЛ. КАПЛИ Д/ПРИЕМА ВНУТРЬ ФЛ./КАП.',
#  'ВАЛОСЕРДИН 25МЛ. КАПЛИ Д/ПРИЕМА ВНУТРЬ ФЛ. /МОСФАРМА/',
#  'ВЕРОШПИРОН 50МГ. №30 КАПС. /ГЕДЕОН РИХТЕР/',
#  'ВИТАПРОСТ 10МГ. №10 СУПП. РЕКТ. /НИЖФАРМ/',
#  'ВОЛЬТАРЕН 25МГ/МЛ. 3МЛ. №5 Р-Р Д/В/М АМП. /НОВАРТИС/ГЛАКСО/',
#  'ГЕКСАЛИЗ №30 ТАБ. Д/РАСС.',
#  'ГЕМАТОГЕН РУССКИЙ ДЕТСКИЙ 40Г. ПЛИТКА /ФАРМ-ПРО/',
#  'ГИПОСАРТ 16МГ. №28 ТАБ.',
#  'ГЛИЦЕРИН 2,11Г. №10 СУПП. РЕКТ. /НИЖФАРМ/',
#  'ГЛИЦИН 100МГ. №100 ТАБ. ПОДЪЯЗЫЧ. /БИОТИКИ/',
#  'ГЛИЦИН 100МГ. №50 ТАБ. ПОДЪЯЗЫЧ. /БИОТИКИ/',
#  'ГЛЮКОЗА 40% 10МЛ. №10 Р-Р Д/ИН. АМП. /ДАЛЬХИМФАРМ/',
#  'ДЕЗЛОРАТАДИН-ВЕЛФАРМ 5МГ. №10 ТАБ. П/О',
#  'ДЕТРАЛЕКС 1000МГ. №60 ТАБ. П/П/О',
#  'ДЕТРИМАКС 2000 240МГ. №60 ТАБ. П/О',
#  'ДИАБЕТОН МВ 60МГ. №30 ТАБ. МОДИФ.ВЫСВ. /СЕРВЬЕ/',
#  'ДИКЛОФЕНАК 100МГ. №20 ТАБ.ПРОЛОНГ. П/О /НИЖФАРМ/ХЕМОФАРМ/',
#  'ДИКЛОФЕНАК 25МГ/МЛ. 3МЛ. №5 Р-Р Д/В/М ВВЕД. АМП. /ХЕМОФАРМ/',
#  'ДИКЛОФЕНАК 50МГ. №20 ТАБ.КШ/РАСТВ. П/О /ХЕМОФАРМ/',
#  'ДОКСИЦИКЛИН СОЛЮШН ТАБЛЕТС 100МГ. №10 ТАБ.ДИСПЕРГ. /АТОЛЛ/ОЗОН/',
#  'ДОКТОР ПЕРЕЦ ЛЕЙКОПЛАСТ. ПЕРЦОВЫЙ 10X18 №1 ПЕРФ. /ВЕРОФАРМ/',
#  'ДОЛГИТ 5% 100Г. КРЕМ Д/НАРУЖ.ПРИМ. ТУБА /ДОЛОРГИТ/',
#  'ДОНАТ МАГНИЙ ВОДА ГАЗ. 1Л. ПЭТ [DONAT]',
#  'ДОНОРМИЛ 15МГ. №30 ТАБ. П/П/О',
#  'ДОРИТРИЦИН №10 ТАБ. Д/РАСС.',
#  'ИБУКЛИН 400МГ.+325МГ. №10 ТАБ. П/П/О',
#  'ИБУПРОФЕН 200МГ. №50 ТАБ. П/О /БОРИСОВСКИЙ/',
#  'ИНГАВИРИН 90МГ. №10 КАПС. /ВАЛЕНТА/',
#  'ИНДОМЕТАЦИН-СОФАРМА 25МГ. №30 ТАБ.КШ/РАСТВ. П/О',
#  'ЙОДА 5% 10МЛ. СПИРТ. Р-Р ФЛ. /ЯРОСЛАВСКАЯ ФФ/',
#  'ЙОДА 5% 25МЛ. №1 СПИРТ. Р-Р Д/НАРУЖ.ПРИМ. ФЛ. /ТУЛЬСКАЯ ФФ/',
#  'КАЛЕНДУЛЫ НАСТОЙКА 25МЛ. ФЛ. /ГИППОКРАТ/',
#  'КАЛИНОВ РОДНИК ВОДА МИНЕР. 0,5Л. Н/ГАЗ.',
#  'КАНЕФРОН Н №60 ТАБ. П/О',
#  'КЕТОРОЛ ЭКСПРЕСС 10МГ. №20 ТАБ. ДИСПЕРГ. /Д-Р РЕДДИС/',
#  'КЛОПИДОГРЕЛ-СЗ 75МГ. №28 ТАБ. П/П/О /СЕВЕРНАЯ ЗВЕЗДА/',
#  'КОМБИЛИПЕН 2МЛ. №10 Р-Р Д/В/М АМП.',
#  'КОНКОР КОР 2,5МГ. №30 ТАБ. П/П/О /МЕРК/',
#  'КОНТЕЙНЕР Д/СБОРА БИОМАТЕРИАЛА 100МЛ. СТЕР. (БАНКА)',
#  'КОНТЕЙНЕР Д/СБОРА БИОМАТЕРИАЛА 120МЛ. УНИВЕРС. СТЕР. (БАНКА)',
#  'КОРВАЛОЛ 25МЛ. КАПЛИ Д/ПРИЕМА ВНУТРЬ ФЛ. И/У /ФАРМСТАНДАРТ ЛЕКСРЕДСТВА/',
#  'КОРНЕРЕГЕЛЬ 5% 10Г. ГЛ. ГЕЛЬ ТУБА',
#  'КРЕМ ДЕТСКИЙ РОМАШКА+ВИТ.А+F 75МЛ. /АВАНТА/',
#  'Карта LOYALITY 0,01Р',
#  'Карта LOYALITY 25Р',
#  'ЛАКОМКА ПОМАДА ГИГИЕН. ЯГОДНЫЙ МИКС 2,8Г. /АВАНТА/',
#  'ЛЕВОМЕКОЛЬ 40МГ/Г.+7,5МГ/Г. 40Г. №1 МАЗЬ Д/НАРУЖ.ПРИМ. ТУБА /НИЖФАРМ/',
#  'ЛЕВОМИЦЕТИН 0,25% 10МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /ЛЕККО/',
#  'ЛЕВОФЛОКСАЦИН 500МГ. №10 ТАБ. П/П/О /ФАРМСТАНДАРТ-ТОМСКХИМФАРМ/',
#  'ЛЕЙКОПЛАСТЫРЬ 1Х500 РУЛОН КОНТ.УПАКОВКА/ПАКЕТ /ВЕРОФАРМ/',
#  'ЛЕЙКОПЛАСТЫРЬ 2Х500 ТКАН.ОСНОВА КАТУШКА КАРТОН /ВЕРОФАРМ/',
#  'ЛЕЙКОПЛАСТЫРЬ БАКТЕР. 2,5Х7,2 №1 /ВЕРОФАРМ/',
#  'ЛЕЙКОПЛАСТЫРЬ БАКТЕР. 4Х10 №1 /ВЕРОФАРМ/',
#  'ЛЕЙКОПЛАСТЫРЬ БАКТЕР. 6X10 №1 /ВЕРОФАРМ/',
#  'ЛЕКРОЛИН 20МГ/МЛ. 10МЛ. №1 ГЛ.КАПЛИ ФЛ. /САНТЭН/',
#  'ЛИЗИНОПРИЛ 10МГ. №60 ТАБ. /ВЕРТЕКС/',
#  'ЛОПЕРАМИД-АКРИХИН 2МГ. №20 КАПС. /АКРИХИН/',
#  'ЛЮКСПЛАСТ ЛЕЙКОПЛАСТ. БАКТЕР. 19Х72ММ ПЕРФ. ТЕЛЕСН. ПОЛИМЕР. №10 [LUXPLAST]',
#  'МАГНЕЛИС В6 №120 ТАБ. П/О',
#  'МАСКА МЕД. ТРЕХСЛОЙНАЯ (3-Х) НА РЕЗИНКЕ №5',
#  'МЕЗИМ-ФОРТЕ №20 ТАБ. П/О /БЕРЛИН-ХЕМИ/',
#  'МЕЗИМ-ФОРТЕ №80 ТАБ. П/О /БЕРЛИН-ХЕМИ/',
#  'МЕКСИДОЛ 125МГ. №50 ТАБ. П/П/О /ФАРМАСОФТ/ЗИО ЗДОРОВЬЕ/',
#  'МЕНОВАЗИН 40МЛ. №1 СПИРТ. Р-Р Д/НАРУЖ.ПРИМ. ФЛ. /САМАРАМЕДПРОМ/',
#  'МЕНОВАЗИН 40МЛ. №1 СПИРТ. Р-Р Д/НАРУЖ.ПРИМ. ФЛ. /ТУЛЬСКАЯ ФФ/',
#  'МЕТИЛУРАЦИЛ 10% 25Г. МАЗЬ Д/МЕСТ. И НАРУЖ.ПРИМ. ТУБА /НИЖФАРМ/',
#  'МЕТРОГИЛ ДЕНТА 20Г. №1 ГЕЛЬ СТОМАТ. ТУБА',
#  'МЕТРОНИДАЗОЛ 250МГ. №20 ТАБ. /МЕДИСОРБ/',
#  'МИГ 400МГ. №20 ТАБ. П/П/О /БЕРЛИН-ХЕМИ/',
#  'МИДОКАЛМ 150МГ. №30 ТАБ. П/П/О /ГЕДЕОН РИХТЕР/',
#  'МИКРОЛАКС 5МЛ. №4 Р-Р Д/РЕКТ. ВВЕД. МИКРОКЛИЗМА',
#  'МИЛДРОНАТ 100МГ/МЛ. 5МЛ. №10 Р-Р Д/В/В,В/М И ПАРАБУЛЬБ. ВВЕД. АМП. /ГРИНДЕКС/',
#  'МОКСОНИДИН-СЗ 0,2МГ. №60 ТАБ. П/П/О /СЕВЕРНАЯ ЗВЕЗДА/',
#  'НАЙЗ 100МГ. №30 ТАБ.',
#  'НАНОПЛАСТ ФОРТЕ ПЛАСТЫРЬ ОБЕЗБОЛ. 9Х12СМ. №3',
#  'НАТРИЯ ХЛОРИД 0,9% 100МЛ. №28 Р-Р Д/ИНФ. /ЭСКОМ/',
#  'НАФТИЗИН 0,1% 15МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. /СЛАВЯНСКАЯ АПТЕКА/',
#  'НИМЕСИЛ 100МГ. 2Г. №30 ГРАН. Д/СУСП. Д/ПРИЕМА ВНУТРЬ ПАК. /ГУИДОТТИ/МЕНАРИНИ/',
#  'НИФЕДИПИН 10МГ. №50 ТАБ. П/П/О /ОЗОН/',
#  'НО-ШПА 40МГ. №24 ТАБ. /ХИНОИН/',
#  'НОЛИПРЕЛ А ФОРТЕ 5МГ.+1,25МГ. №30 ТАБ. П/П/О',
#  'НОЛЬПАЗА 20МГ. №14 ТАБ.КШ/РАСТВ. П/О /KRKA/',
#  'НОЛЬПАЗА 20МГ. №28 ТАБ.КШ/РАСТВ. П/О /KRKA/',
#  'НУРОФЕН 100МГ/5МЛ. 100МЛ. СУСП. КЛУБНИКА Д/ДЕТЕЙ ФЛ. /РЕКИТТ БЕНКИЗЕР/',
#  'НУРОФЕН ЭКСПРЕСС ФОРТЕ 400МГ. №20 КАПС. /РЕКИТТ БЕНКИЗЕР/',
#  'ОМЕЗ 20МГ. №30 КАПС. /Д-Р РЕДДИ/',
#  'ОМЕПРАЗОЛ 20МГ. №30 КАПС. /ПРОИЗВОДСТВО МЕДИКАМЕНТОВ/',
#  'ОФТАН-КАТАХРОМ 10МЛ. ГЛ.КАПЛИ ФЛ.',
#  'ПАКЕТ',
#  'ПАНАНГИН 158МГ+140МГ. №50 ТАБ. П/П/О /ГЕДЕОН РИХТЕР/',
#  'ПАНКРЕАТИН 25ЕД №60 ТАБ.КШ/РАСТВ. П/О БАНКА /БИОСИНТЕЗ/',
#  'ПАНКРЕАТИН 30ЕД №60 ТАБ.КШ/РАСТВ. П/О БАНКА /ФАРМПРОЕКТ/',
#  'ПАРАЦЕТАМОЛ 500МГ. №20 ТАБ. /ФАРМСТАНДАРТ/',
#  'ПАСКАЛЬ ШПРИЦ 3-Х КОМП. 3МЛ. С ИГЛОЙ 22G 0,7Х40ММ. №10 [PASCAL]',
#  'ПАСКАЛЬ ШПРИЦ 3-Х КОМП. 5МЛ. С ИГЛОЙ 22G 0,7Х30ММ. №10 [PASCAL]',
#  'ПЕНТАЛГИН №24 ТАБ. П/П/О /ОТИСИФАРМ/',
#  'ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №1 Р-Р ДЕЗ.СР-ВО ФЛ. (НДС 20%)',
#  'ПЕРИНЕВА 4МГ. №30 ТАБ. /KRKA/',
#  'ПИКАМИЛОН 20МГ. №30 ТАБ. /ФАРМСТАНДАРТ/',
#  'ПОЛИДЕКСА С ФЕНИЛЭФРИНОМ 15МЛ. НАЗАЛ.СПРЕЙ ФЛ.',
#  'ПУЛЬМИКОРТ 0,25МГ/МЛ. 2МЛ. №20 СУСП. Д/ИНГ. КОНТ. /АСТРА ЗЕНЕКА/',
#  'ПУСТЫРНИКА НАСТОЙКА 25МЛ. ФЛ. /ГИППОКРАТ/',
#  'ПУСТЫРНИКА ЭКСТРАКТ 14МГ. №50 ТАБ. /ФАРМСТАНДАРТ/',
#  'РИГЕВИДОН 0,15МГ+0,03МГ. №63 (21Х3) ТАБ. П/О /ГЕДЕОН РИХТЕР/',
#  'РИНОНОРМ-ТЕВА 0,1% 140МКГ/ДОЗА 20МЛ. НАЗАЛ.СПРЕЙ ФЛ. /ТЕВА/',
#  'РИНОРУС 0,1% 10МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. И/У /СИНТЕЗ/',
#  'РИНОСТОП 0,1% 10МЛ. НАЗАЛ.КАПЛИ ФЛ./КАП. /ОТИСИФАРМ/ЛЕККО/ФАРМСТАНДАРТ ЛЕКСРЕДСТВА/',
#  'РИНОСТОП 0,1% 15МЛ. НАЗАЛ.СПРЕЙ ФЛ. /ОТИСИФАРМ/ЛЕККО/ФАРМСТАНДАРТ ЛЕКСРЕДСТВА/',
#  'РОМАШКИ ЦВЕТКИ 1,5Г. №20 ПАК. /КРАСНОГОРСК/',
#  'САЛИПОД ЛЕЙКОПЛАСТ. МОЗОЛЬНЫЙ 6Х10СМ. /ВЕРОФАРМ/',
#  'САЛИЦИЛОВАЯ К-ТА 2% 40МЛ. №1 СПИРТ. Р-Р Д/НАРУЖ.ПРИМ. ФЛ. /ИВАНОВСКАЯ ФФ/',
#  'СВЯТОЙ ИСТОЧНИК ВОДА ПИТЬЕВАЯ 0,5Л. Н/ГАЗ. ПЭТ',
#  'СИГНИЦЕФ 0,5% 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /СЕНТИСС/ПРОМЕД/',
#  'СИЛЬВЕР КАПИТАН БАТОНЧИК КОКОС БЕЛ.ГЛАЗ. 50Г.',
#  'СИНАФЛАН 0,025% 15Г. МАЗЬ Д/НАРУЖ.ПРИМ. ТУБА /МУРОМСКИЙ ЗАВОД/',
#  'СНУП 0,1% 90МКГ/ДОЗА 15МЛ. НАЗАЛ.СПРЕЙ ФЛ. /ШТАДА/',
#  'СОРБИФЕР ДУРУЛЕС 320МГ/60МГ. №50 ТАБ. П/О',
#  'СОТАГЕКСАЛ 80МГ. №20 ТАБ. /ГЕКСАЛ АГ/',
#  'СПЛАТ ЗУБ.ПАСТА ЛЕЧЕБНЫЕ ТРАВЫ 100МЛ. [SPLAT]',
#  'СТАРЫЙ ИСТОЧНИК СЛАВЯНОВСКАЯ ВОДА МИНЕР. ЭЛИТНАЯ 1Л.',
#  'СТЕЛЛАНИН 3% 20Г. МАЗЬ Д/НАРУЖ.ПРИМ. ТУБА',
#  'СТОПСЕПТ ПЛЮС 90% 100МЛ. ДЕЗ.СР-ВО ФЛ.',
#  'СТРЕПТОЦИД 10Г. №1 ПОР. Д/НАРУЖ.ПРИМ. БАНКА ДОЗ. /ЛЕКАРЬ/',
#  'СФМ СИСТЕМА Д/ПЕРЕЛИВ. ИНФУЗ. Р-РОВ №1 ПЛАСТ.ИГЛА [SFM]',
#  'СФМ ШПРИЦ 2МЛ. 3-Х КОМП. 0,63Х32ММ 23G №100 [SFM]',
#  'СФМ ШПРИЦ 5МЛ. 3-Х КОМП. 0,7Х40ММ 22G №100 [SFM]',
#  'ТАУРИН 4% 10МЛ. ГЛ.КАПЛИ ФЛ./КАП. /СЛАВЯНСКАЯ АПТЕКА/',
#  'ТАУФОН 4% 10МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /ОТИСИФАРМ/ФАРМСТАНДАРТ/',
#  'ТЕРАФЛЮ ЭКСТРА ЛИМОН ОТ ГРИППА И ПРОСТУДЫ 15Г. №10 ПОР. Д/Р-РА Д/ПРИЕМА ВНУТРЬ ПАК.',
#  'ТЕТРАЦИКЛИНОВАЯ 1% 5Г. ГЛ. МАЗЬ ТУБА /ТАТХИМФАРМ/',
#  'ТОЛПЕРИЗОН 150МГ. №30 ТАБ. П/П/О /МЕДИСОРБ/',
#  'ТРИМЕТАЗИДИН-АКОС МВ 35МГ. №60 ТАБ. МОДИФ.ВЫСВ. /БИОКОМ/',
#  'ТРОКСЕРУТИН ВРАМЕД 2% 40Г. ГЕЛЬ Д/НАРУЖ.ПРИМ. ТУБА /СОФАРМА/',
#  'УГОЛЬ АКТИВИРОВАННЫЙ 250МГ. №50 ТАБ. /ФАРМСТАНДАРТ ЛЕКСРЕДСТВА/',
#  'ФЕРРОГЕМАТОГЕН 50Г. ПАСТИЛКА ЖЕВ. (ПЛИТКА)',
#  'ФЛУИМУЦИЛ 600МГ. №10 ШИП.ТАБ. /ЗАМБОН/',
#  'ФОСФОГЛИВ ФОРТЕ 65МГ+300МГ. №50 КАПС. /ФАРМСТАНДАРТ/',
#  'ФУКОРЦИН 25МЛ. Р-Р Д/НАРУЖ.ПРИМ. ФЛ. /ТУЛЬСКАЯ ФФ/',
#  'ФУРАЦИЛИН АВЕКСИМА 20МГ. №10 ШИП.ТАБ. Д/Р-РА Д/МЕСТ. И НАРУЖ.ПРИМ.',
#  'ХЕЛП БИНТ СТЕР. 7МХ14СМ И/У [HELP]',
#  'ЦИАНОКОБАЛАМИН 0,5МГ/МЛ. 1МЛ. №10 Р-Р Д/ИН. АМП. (ВИТАМИН В12) /ДАЛЬХИМФАРМ/',
#  'ЦИПРОЛЕТ А 500МГ.+600МГ. №10 ТАБ. П/О',
#  'ЦИСТОН №100 ТАБ.',
#  'ЦИТРАМОН П №10 ТАБ. /ФАРМСТАНДАРТ/',
#  'ЦИТРАМОН П №20 ТАБ. /МЕДИСОРБ/',
#  'ЦИТРАМОН П №20 ТАБ. /ФАРМСТАНДАРТ/',
#  'ЭВЕРС-ЛАЙФ САЛФЕТКА СТЕР. 2-Х СЛ. 16Х14СМ. №10 [EVERS LIFE]',
#  'ЭВО ПАНТЕНОЛ ПОМАДА ГИГИЕН. 2,8Г. [EVO] /АВАНТА/',
#  'ЭЛИКВИС 5МГ. №60 ТАБ. П/П/О /ПФАЙЗЕР/БРИСТОЛ-МАЙЕРС/',
#  'ЭМОКСИПИН 10МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ. КРЫШ/КАП.',
#  'ЭНАЛАПРИЛ 5МГ. №20 ТАБ. /ХЕМОФАРМ/',
#  'ЭСВИЦИН СР-ВО П/ОБЛЫСЕНИЯ ЛОСЬОН-ТОНИК 250МЛ. ФЛ. /ВИО-ФАРМ/']

# %% [markdown]
# Оставим только эти товары для анализа и рассчитаем для каждого товара коэффициент вариативности.

# %%
df = df[df['DR_NDrugs'].isin(xyz_names)]
df = df.groupby('DR_NDrugs', as_index= False).apply(lambda x: x.std()/x.mean())
df
# Out:
#                                              DR_NDrugs  DR_Kol
# 0             L-ТИРОКСИН 50МКГ. №50 ТАБ. /БЕРЛИН ХЕМИ/    0.00
# 1            L-ТИРОКСИН 75МКГ. №100 ТАБ. /БЕРЛИН ХЕМИ/    0.47
# 2    АЗАРГА 10МГ/МЛ.+5МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП.    0.00
# 3             АМОКСИЦИЛЛИН 500МГ. №16 КАПС. /ХЕМОФАРМ/    0.47
# 4    АРБИДОЛ МАКСИМУМ 200МГ. №10 КАПС. /ОТИСИФАРМ/Ф...    0.43
# ..                                                 ...     ...
# 177   ЭВО ПАНТЕНОЛ ПОМАДА ГИГИЕН. 2,8Г. [EVO] /АВАНТА/    0.47
# 178  ЭЛИКВИС 5МГ. №60 ТАБ. П/П/О /ПФАЙЗЕР/БРИСТОЛ-М...    0.00
# 179  ЭМОКСИПИН 10МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ. КРЫШ/КАП.    0.47
# 180                 ЭНАЛАПРИЛ 5МГ. №20 ТАБ. /ХЕМОФАРМ/    0.47
# 181  ЭСВИЦИН СР-ВО П/ОБЛЫСЕНИЯ ЛОСЬОН-ТОНИК 250МЛ. ...    0.29
#
# [182 rows x 2 columns]

# %% [markdown]
# Промаркируем в зависимости от рассчитаннызх значений на XYZ-группы.

# %%
df['XYZ'] = np.where(df['DR_Kol'] < 0.1, 'X', np.where(df['DR_Kol'] < 0.25, 'Y', 'Z'))

# %%
df.head()
# Out:
#                                            DR_NDrugs  DR_Kol XYZ
# 0           L-ТИРОКСИН 50МКГ. №50 ТАБ. /БЕРЛИН ХЕМИ/    0.00   X
# 1          L-ТИРОКСИН 75МКГ. №100 ТАБ. /БЕРЛИН ХЕМИ/    0.47   Z
# 2  АЗАРГА 10МГ/МЛ.+5МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП.    0.00   X
# 3           АМОКСИЦИЛЛИН 500МГ. №16 КАПС. /ХЕМОФАРМ/    0.47   Z
# 4  АРБИДОЛ МАКСИМУМ 200МГ. №10 КАПС. /ОТИСИФАРМ/Ф...    0.43   Z
